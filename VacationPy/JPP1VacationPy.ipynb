# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import time
from scipy.stats import linregress
from matplotlib import pyplot as plt

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")



# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         faya  18.3851   42.4509     22.06        35          21
# 1        1      farsund  58.0948    6.8047     13.30       100           0
# 2        2  new norfolk -42.7826  147.0587     11.72        58          12
# 3        3    jamestown  42.0970  -79.2353      5.77        77         100
# 4        4      lanzhou  36.0564  103.7922     14.53        48          59
#
#    Wind Speed Country        Date
# 0        2.60      SA  1666108228
# 1        7.65      NO  1666108228
# 2        1.34      AU  1666108230
# 3        9.77      US  1666107934
# 4        1.20      CN  1666108230

# %%
city_data_df.describe()
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City_ID     577 non-null    int64
#  1   City        577 non-null    object
#  2   Lat         577 non-null    float64
#  3   Lng         577 non-null    float64
#  4   Max Temp    577 non-null    float64
#  5   Humidity    577 non-null    int64
#  6   Cloudiness  577 non-null    int64
#  7   Wind Speed  577 non-null    float64
#  8   Country     574 non-null    object
#  9   Date        577 non-null    int64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 45.2+ KB

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Step1 1 Configure the map plot
# Configure the map
city_data_Hum_map = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 2,
    color = "City",
    hover_cols = ["city", "Humity"]
)


# Step 1 2 Display the map
city_data_Hum_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
#  Step2 1 
# Narrow down the city_data_df DataFrame to find your ideal weather condition. 
#For example:
#  A max temperature lower than 27 degrees but higher than 21
#  Wind speed less than 4.5 m/s
#  Zero cloudiness
ideal_weather_df = city_data_df[
    (city_data_df["Max Temp"] < 25) &
    (city_data_df["Max Temp"] > 21) &
    (city_data_df["Wind Speed"] < 3.5) &
    (city_data_df["Cloudiness"] >= 0)
]

# Step2 2    Drop any rows with null values
city_data_df.dropna(inplace=True)

# Display the filtered DataFrame
ideal_weather_df
# Out:
#      City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 0          0            faya  18.3851   42.4509     22.06        35
# 19        19    puerto ayora  -0.7393  -90.3518     22.98        82
# 20        20          avarua -21.2078 -159.7750     22.03        73
# 52        52         businga   3.3333   20.8833     24.82        87
# 53        53            lasa  46.6166   10.7002     23.49        68
# 54        54           vaini -21.2000 -175.2000     23.09       100
# 63        63           banda  25.4833   80.3333     24.62        52
# 81        81   makakilo city  21.3469 -158.0858     21.66        81
# 86        86         rafaela -31.2503  -61.4867     21.10        42
# 124      124          muncar  -8.4333  114.3333     23.87        96
# 152      152         kahului  20.8947 -156.4700     23.80        60
# 157      157       innisfail -17.5333  146.0333     24.83        74
# 165      165        ambilobe -13.2000   49.0500     24.36        62
# 184      184       sembakung   3.8167  117.2500     23.47        99
# 189      189     grand gaube -20.0064   57.6608     22.22        65
# 207      207    port moresby  -9.4431  147.1797     23.68        94
# 208      208        meulaboh   4.1363   96.1285     24.82        88
# 211      211          laguna  38.4210 -121.4238     21.67        79
# 220      220           yumbe   3.4651   31.2469     21.32        84
# 221      221   pangkalanbuun  -2.6833  111.6167     23.87        96
# 229      229   san cristobal   7.7669  -72.2250     22.10        45
# 233      233         makokou   0.5738   12.8642     23.32        95
# 240      240     tikaitnagar  26.9500   81.5833     23.56        59
# 241      241           sembe   1.6481   14.5806     24.54        91
# 265      265     san quintin  30.4833 -115.9500     21.20        74
# 298      298        valdivia -39.8142  -73.2459     21.05        63
# 334      334          kailua  21.4022 -157.7394     22.47        89
# 337      337       mount isa -20.7333  139.5000     21.87       100
# 338      338          mahina -17.5065 -149.4890     23.87        83
# 340      340   santa rosalia  27.3167 -112.2833     24.62        56
# 354      354        bengkulu  -3.8004  102.2655     24.34        90
# 355      355         honiara  -9.4333  159.9500     24.83        85
# 363      363          narwar  25.6500   77.9000     22.35        55
# 375      375    port hedland -20.3167  118.5667     21.03        73
# 381      381       roebourne -20.7833  117.1333     23.48        65
# 421      421          stolac  43.0844   17.9575     24.88        68
# 432      432        denpasar  -8.6500  115.2167     24.84       100
# 439      439          katobu  -4.9408  122.5276     24.42        94
# 450      450        samandag  36.0842   35.9771     21.85        80
# 473      473        singkang   2.1006  102.7994     24.57        89
# 475      475          nabire  -3.3667  135.4833     24.46        91
# 501      501           kapit   2.0167  112.9333     23.38        99
# 509      509        bhandara  21.1667   79.6500     23.48        86
# 516      516  guerrero negro  27.9769 -114.0611     23.17        68
# 530      530           isiro   2.7739   27.6160     24.06        73
# 552      552   bambanglipuro  -7.9500  110.2833     24.88        87
# 563      563        ilhabela -23.7781  -45.3581     22.67        88
# 567      567       sangamner  19.5667   74.2167     23.82        85
# 569      569          ranong   9.9658   98.6348     24.34        93
#
#      Cloudiness  Wind Speed Country        Date
# 0            21        2.60      SA  1666108228
# 19           41        1.79      EC  1666108242
# 20           20        2.57      CK  1666108220
# 52           99        0.97      CD  1666108261
# 53           11        2.01      IT  1666108019
# 54           20        2.57      TO  1666108262
# 63            0        2.68      IN  1666108268
# 81            0        2.57      US  1666108282
# 86          100        1.79      AR  1666108109
# 124         100        0.69      ID  1666108310
# 152           0        3.09      US  1666108246
# 157          87        1.53      AU  1666108331
# 165          46        2.28      MG  1666108335
# 184          99        0.21      ID  1666108349
# 189          47        0.89      MU  1666108353
# 207          40        2.57      PG  1666108361
# 208         100        1.23      ID  1666108362
# 211           0        2.06      US  1666108364
# 220          83        1.37      UG  1666108367
# 221         100        0.90      ID  1666108368
# 229          46        0.57      VE  1666108372
# 233          97        1.00      GA  1666108374
# 240           0        0.35      IN  1666108378
# 241          84        0.23      CG  1666108378
# 265           0        1.37      MX  1666108394
# 298          29        2.71      CL  1666108414
# 334           1        1.18      US  1666108432
# 337          40        2.57      AU  1666108425
# 338          75        1.03      PF  1666108434
# 340           0        0.74      MX  1666108436
# 354         100        1.80      ID  1666108381
# 355          45        2.39      SB  1666108443
# 363           0        1.29      IN  1666108449
# 375           0        3.09      AU  1666108455
# 381           0        2.95      AU  1666108458
# 421           0        0.80      BA  1666108483
# 432          75        0.00      ID  1666108489
# 439          90        1.04      ID  1666108493
# 450           1        2.31      TR  1666108498
# 473          79        0.84      MY  1666108510
# 475         100        1.57      ID  1666108512
# 501         100        0.53      MY  1666108528
# 509          91        1.95      IN  1666108534
# 516           0        0.89      MX  1666108537
# 530          81        0.14      CD  1666108543
# 552         100        0.65      ID  1666108553
# 563          95        2.32      BR  1666108558
# 567         100        2.28      IN  1666108559
# 569         100        1.44      TH  1666108330

# %%
ideal_weather_df.describe()
ideal_weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, 0 to 569
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City_ID     49 non-null     int64
#  1   City        49 non-null     object
#  2   Lat         49 non-null     float64
#  3   Lng         49 non-null     float64
#  4   Max Temp    49 non-null     float64
#  5   Humidity    49 non-null     int64
#  6   Cloudiness  49 non-null     int64
#  7   Wind Speed  49 non-null     float64
#  8   Country     49 non-null     object
#  9   Date        49 non-null     int64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 4.2+ KB

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather_df[['City', 'Country', 'Lat', 'Lng', 'Humidity', "Max Temp","Wind Speed"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df
# Out:
#                City Country      Lat       Lng  Humidity  Max Temp  \
# 0              faya      SA  18.3851   42.4509        35     22.06
# 19     puerto ayora      EC  -0.7393  -90.3518        82     22.98
# 20           avarua      CK -21.2078 -159.7750        73     22.03
# 52          businga      CD   3.3333   20.8833        87     24.82
# 53             lasa      IT  46.6166   10.7002        68     23.49
# 54            vaini      TO -21.2000 -175.2000       100     23.09
# 63            banda      IN  25.4833   80.3333        52     24.62
# 81    makakilo city      US  21.3469 -158.0858        81     21.66
# 86          rafaela      AR -31.2503  -61.4867        42     21.10
# 124          muncar      ID  -8.4333  114.3333        96     23.87
# 152         kahului      US  20.8947 -156.4700        60     23.80
# 157       innisfail      AU -17.5333  146.0333        74     24.83
# 165        ambilobe      MG -13.2000   49.0500        62     24.36
# 184       sembakung      ID   3.8167  117.2500        99     23.47
# 189     grand gaube      MU -20.0064   57.6608        65     22.22
# 207    port moresby      PG  -9.4431  147.1797        94     23.68
# 208        meulaboh      ID   4.1363   96.1285        88     24.82
# 211          laguna      US  38.4210 -121.4238        79     21.67
# 220           yumbe      UG   3.4651   31.2469        84     21.32
# 221   pangkalanbuun      ID  -2.6833  111.6167        96     23.87
# 229   san cristobal      VE   7.7669  -72.2250        45     22.10
# 233         makokou      GA   0.5738   12.8642        95     23.32
# 240     tikaitnagar      IN  26.9500   81.5833        59     23.56
# 241           sembe      CG   1.6481   14.5806        91     24.54
# 265     san quintin      MX  30.4833 -115.9500        74     21.20
# 298        valdivia      CL -39.8142  -73.2459        63     21.05
# 334          kailua      US  21.4022 -157.7394        89     22.47
# 337       mount isa      AU -20.7333  139.5000       100     21.87
# 338          mahina      PF -17.5065 -149.4890        83     23.87
# 340   santa rosalia      MX  27.3167 -112.2833        56     24.62
# 354        bengkulu      ID  -3.8004  102.2655        90     24.34
# 355         honiara      SB  -9.4333  159.9500        85     24.83
# 363          narwar      IN  25.6500   77.9000        55     22.35
# 375    port hedland      AU -20.3167  118.5667        73     21.03
# 381       roebourne      AU -20.7833  117.1333        65     23.48
# 421          stolac      BA  43.0844   17.9575        68     24.88
# 432        denpasar      ID  -8.6500  115.2167       100     24.84
# 439          katobu      ID  -4.9408  122.5276        94     24.42
# 450        samandag      TR  36.0842   35.9771        80     21.85
# 473        singkang      MY   2.1006  102.7994        89     24.57
# 475          nabire      ID  -3.3667  135.4833        91     24.46
# 501           kapit      MY   2.0167  112.9333        99     23.38
# 509        bhandara      IN  21.1667   79.6500        86     23.48
# 516  guerrero negro      MX  27.9769 -114.0611        68     23.17
# 530           isiro      CD   2.7739   27.6160        73     24.06
# 552   bambanglipuro      ID  -7.9500  110.2833        87     24.88
# 563        ilhabela      BR -23.7781  -45.3581        88     22.67
# 567       sangamner      IN  19.5667   74.2167        85     23.82
# 569          ranong      TH   9.9658   98.6348        93     24.34
#
#      Wind Speed Hotel Name
# 0          2.60
# 19         1.79
# 20         2.57
# 52         0.97
# 53         2.01
# 54         2.57
# 63         2.68
# 81         2.57
# 86         1.79
# 124        0.69
# 152        3.09
# 157        1.53
# 165        2.28
# 184        0.21
# 189        0.89
# 207        2.57
# 208        1.23
# 211        2.06
# 220        1.37
# 221        0.90
# 229        0.57
# 233        1.00
# 240        0.35
# 241        0.23
# 265        1.37
# 298        2.71
# 334        1.18
# 337        2.57
# 338        1.03
# 340        0.74
# 354        1.80
# 355        2.39
# 363        1.29
# 375        3.09
# 381        2.95
# 421        0.80
# 432        0.00
# 439        1.04
# 450        2.31
# 473        0.84
# 475        1.57
# 501        0.53
# 509        1.95
# 516        0.89
# 530        0.14
# 552        0.65
# 563        2.32
# 567        2.28
# 569        1.44

# %%
# Function to get hotel name using Geoapify API
def get_hotel_name(lat, lng):
    params = {
        "categories": "accommodations.hotel",
        "apikey": geoapify_key,
        "limit": 1,
        "radius": 10000,  # Set the radius to 10,000 meters
        "lat": lat,
        "lon": lng
    }
    response = requests.get("https://api.geoapify.com/v1/places", params=params)
    data = response.json()
    hotel_name = data['features'][0]['properties']['name'] if data['features'] else "Not found"
    return hotel_name

# Iterate over each row in the hotel_df DataFrame
#for index, row in hotel_df.iterrows():
    lat = row['Lat']
    lng = row['Lng']
    hotel_name = get_hotel_name(lat, lng)
    hotel_df.at[index, 'Hotel Name'] = hotel_name

# Display the updated hotel_df with hotel names filled in
#print(hotel_df)
# Out:
#                City Country      Lat       Lng  Humidity  Max Temp  \
# 0              faya      SA  18.3851   42.4509        35     22.06
# 19     puerto ayora      EC  -0.7393  -90.3518        82     22.98
# 20           avarua      CK -21.2078 -159.7750        73     22.03
# 52          businga      CD   3.3333   20.8833        87     24.82
# 53             lasa      IT  46.6166   10.7002        68     23.49
# 54            vaini      TO -21.2000 -175.2000       100     23.09
# 63            banda      IN  25.4833   80.3333        52     24.62
# 81    makakilo city      US  21.3469 -158.0858        81     21.66
# 86          rafaela      AR -31.2503  -61.4867        42     21.10
# 124          muncar      ID  -8.4333  114.3333        96     23.87
# 152         kahului      US  20.8947 -156.4700        60     23.80
# 157       innisfail      AU -17.5333  146.0333        74     24.83
# 165        ambilobe      MG -13.2000   49.0500        62     24.36
# 184       sembakung      ID   3.8167  117.2500        99     23.47
# 189     grand gaube      MU -20.0064   57.6608        65     22.22
# 207    port moresby      PG  -9.4431  147.1797        94     23.68
# 208        meulaboh      ID   4.1363   96.1285        88     24.82
# 211          laguna      US  38.4210 -121.4238        79     21.67
# 220           yumbe      UG   3.4651   31.2469        84     21.32
# 221   pangkalanbuun      ID  -2.6833  111.6167        96     23.87
# 229   san cristobal      VE   7.7669  -72.2250        45     22.10
# 233         makokou      GA   0.5738   12.8642        95     23.32
# 240     tikaitnagar      IN  26.9500   81.5833        59     23.56
# 241           sembe      CG   1.6481   14.5806        91     24.54
# 265     san quintin      MX  30.4833 -115.9500        74     21.20
# 298        valdivia      CL -39.8142  -73.2459        63     21.05
# 334          kailua      US  21.4022 -157.7394        89     22.47
# 337       mount isa      AU -20.7333  139.5000       100     21.87
# 338          mahina      PF -17.5065 -149.4890        83     23.87
# 340   santa rosalia      MX  27.3167 -112.2833        56     24.62
# 354        bengkulu      ID  -3.8004  102.2655        90     24.34
# 355         honiara      SB  -9.4333  159.9500        85     24.83
# 363          narwar      IN  25.6500   77.9000        55     22.35
# 375    port hedland      AU -20.3167  118.5667        73     21.03
# 381       roebourne      AU -20.7833  117.1333        65     23.48
# 421          stolac      BA  43.0844   17.9575        68     24.88
# 432        denpasar      ID  -8.6500  115.2167       100     24.84
# 439          katobu      ID  -4.9408  122.5276        94     24.42
# 450        samandag      TR  36.0842   35.9771        80     21.85
# 473        singkang      MY   2.1006  102.7994        89     24.57
# 475          nabire      ID  -3.3667  135.4833        91     24.46
# 501           kapit      MY   2.0167  112.9333        99     23.38
# 509        bhandara      IN  21.1667   79.6500        86     23.48
# 516  guerrero negro      MX  27.9769 -114.0611        68     23.17
# 530           isiro      CD   2.7739   27.6160        73     24.06
# 552   bambanglipuro      ID  -7.9500  110.2833        87     24.88
# 563        ilhabela      BR -23.7781  -45.3581        88     22.67
# 567       sangamner      IN  19.5667   74.2167        85     23.82
# 569          ranong      TH   9.9658   98.6348        93     24.34
#
#      Wind Speed Hotel Name
# 0          2.60
# 19         1.79
# 20         2.57
# 52         0.97
# 53         2.01
# 54         2.57
# 63         2.68
# 81         2.57
# 86         1.79
# 124        0.69
# 152        3.09
# 157        1.53
# 165        2.28
# 184        0.21
# 189        0.89
# 207        2.57
# 208        1.23
# 211        2.06
# 220        1.37
# 221        0.90
# 229        0.57
# 233        1.00
# 240        0.35
# 241        0.23
# 265        1.37
# 298        2.71
# 334        1.18
# 337        2.57
# 338        1.03
# 340        0.74
# 354        1.80
# 355        2.39
# 363        1.29
# 375        3.09
# 381        2.95
# 421        0.80
# 432        0.00
# 439        1.04
# 450        2.31
# 473        0.84
# 475        1.57
# 501        0.53
# 509        1.95
# 516        0.89
# 530        0.14
# 552        0.65
# 563        2.32
# 567        2.28
# 569        1.44

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {"categories": "accommodation.hotel",
    "apiKey": geoapify_key, "limit" :20
    }

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row['Lat']
    longitude = row['Lng']
     
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    print( name_address.status_code)
   
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
       # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# 200
# faya - nearest hotel: No hotel found
# 200
# puerto ayora - nearest hotel: Hostal La Mirada De Solitario George
# 200
# avarua - nearest hotel: Paradise Inn
# 200
# businga - nearest hotel: Hôtel Roho
# 200
# lasa - nearest hotel: Hotel "Drei Kreuz"
# 200
# vaini - nearest hotel: Keleti International Resort
# 200
# banda - nearest hotel: #acnindiafy21
# 200
# makakilo city - nearest hotel: Embassy Suites by Hilton Oahu Kapolei
# 200
# rafaela - nearest hotel: Parra Hotel & Suites
# 200
# muncar - nearest hotel: No hotel found
# 200
# kahului - nearest hotel: Maui Seaside Hotel
# 200
# innisfail - nearest hotel: No hotel found
# 200
# ambilobe - nearest hotel: Hôtel National
# 200
# sembakung - nearest hotel: No hotel found
# 200
# grand gaube - nearest hotel: Hotel Lux- Grand Gaube
# 200
# port moresby - nearest hotel: The Sanctuary Hotel and Spa
# 200
# meulaboh - nearest hotel: Hotel Meuligou
# 200
# laguna - nearest hotel: Holiday Inn Express & Suites
# 200
# yumbe - nearest hotel: Bayan Yumbe Hotel
# 200
# pangkalanbuun - nearest hotel: Hotel Tiara
# 200
# san cristobal - nearest hotel: Terra Sur
# 200
# makokou - nearest hotel: Motel des voyageurs
# 200
# tikaitnagar - nearest hotel: No hotel found
# 200
# sembe - nearest hotel: No hotel found
# 200
# san quintin - nearest hotel: Jardines Hotel
# 200
# valdivia - nearest hotel: Esmeralda
# 200
# kailua - nearest hotel: No hotel found
# 200
# mount isa - nearest hotel: Ibis Styles
# 200
# mahina - nearest hotel: Motu Martin
# 200
# santa rosalia - nearest hotel: Sol y Mar
# 200
# bengkulu - nearest hotel: Dena Hotel
# 200
# honiara - nearest hotel: King Solomon Hotel
# 200
# narwar - nearest hotel: No hotel found
# 200
# port hedland - nearest hotel: The Esplanade Hotel
# 200
# roebourne - nearest hotel: No hotel found
# 200
# stolac - nearest hotel: Bregava
# 200
# denpasar - nearest hotel: Bunk Bed Hotel Denpasar Bali
# 200
# katobu - nearest hotel: No hotel found
# 200
# samandag - nearest hotel: Almina Apart Hotel
# 200
# singkang - nearest hotel: No hotel found
# 200
# nabire - nearest hotel: Hotel Anggrek
# 200
# kapit - nearest hotel: Haip
# 200
# bhandara - nearest hotel: Hotel Royal Plaza
# 200
# guerrero negro - nearest hotel: Plaza sal paraiso
# 200
# isiro - nearest hotel: Hôtel Magbetu
# 200
# bambanglipuro - nearest hotel: Puri Ganjuran
# 200
# ilhabela - nearest hotel: Vila Kebaya
# 200
# sangamner - nearest hotel: Joshi Hotel
# 200
# ranong - nearest hotel: Rattana Sin Hotel
#                City Country      Lat       Lng  Humidity  Max Temp  \
# 0              faya      SA  18.3851   42.4509        35     22.06
# 19     puerto ayora      EC  -0.7393  -90.3518        82     22.98
# 20           avarua      CK -21.2078 -159.7750        73     22.03
# 52          businga      CD   3.3333   20.8833        87     24.82
# 53             lasa      IT  46.6166   10.7002        68     23.49
# 54            vaini      TO -21.2000 -175.2000       100     23.09
# 63            banda      IN  25.4833   80.3333        52     24.62
# 81    makakilo city      US  21.3469 -158.0858        81     21.66
# 86          rafaela      AR -31.2503  -61.4867        42     21.10
# 124          muncar      ID  -8.4333  114.3333        96     23.87
# 152         kahului      US  20.8947 -156.4700        60     23.80
# 157       innisfail      AU -17.5333  146.0333        74     24.83
# 165        ambilobe      MG -13.2000   49.0500        62     24.36
# 184       sembakung      ID   3.8167  117.2500        99     23.47
# 189     grand gaube      MU -20.0064   57.6608        65     22.22
# 207    port moresby      PG  -9.4431  147.1797        94     23.68
# 208        meulaboh      ID   4.1363   96.1285        88     24.82
# 211          laguna      US  38.4210 -121.4238        79     21.67
# 220           yumbe      UG   3.4651   31.2469        84     21.32
# 221   pangkalanbuun      ID  -2.6833  111.6167        96     23.87
# 229   san cristobal      VE   7.7669  -72.2250        45     22.10
# 233         makokou      GA   0.5738   12.8642        95     23.32
# 240     tikaitnagar      IN  26.9500   81.5833        59     23.56
# 241           sembe      CG   1.6481   14.5806        91     24.54
# 265     san quintin      MX  30.4833 -115.9500        74     21.20
# 298        valdivia      CL -39.8142  -73.2459        63     21.05
# 334          kailua      US  21.4022 -157.7394        89     22.47
# 337       mount isa      AU -20.7333  139.5000       100     21.87
# 338          mahina      PF -17.5065 -149.4890        83     23.87
# 340   santa rosalia      MX  27.3167 -112.2833        56     24.62
# 354        bengkulu      ID  -3.8004  102.2655        90     24.34
# 355         honiara      SB  -9.4333  159.9500        85     24.83
# 363          narwar      IN  25.6500   77.9000        55     22.35
# 375    port hedland      AU -20.3167  118.5667        73     21.03
# 381       roebourne      AU -20.7833  117.1333        65     23.48
# 421          stolac      BA  43.0844   17.9575        68     24.88
# 432        denpasar      ID  -8.6500  115.2167       100     24.84
# 439          katobu      ID  -4.9408  122.5276        94     24.42
# 450        samandag      TR  36.0842   35.9771        80     21.85
# 473        singkang      MY   2.1006  102.7994        89     24.57
# 475          nabire      ID  -3.3667  135.4833        91     24.46
# 501           kapit      MY   2.0167  112.9333        99     23.38
# 509        bhandara      IN  21.1667   79.6500        86     23.48
# 516  guerrero negro      MX  27.9769 -114.0611        68     23.17
# 530           isiro      CD   2.7739   27.6160        73     24.06
# 552   bambanglipuro      ID  -7.9500  110.2833        87     24.88
# 563        ilhabela      BR -23.7781  -45.3581        88     22.67
# 567       sangamner      IN  19.5667   74.2167        85     23.82
# 569          ranong      TH   9.9658   98.6348        93     24.34
#
#      Wind Speed                             Hotel Name
# 0          2.60                         No hotel found
# 19         1.79   Hostal La Mirada De Solitario George
# 20         2.57                           Paradise Inn
# 52         0.97                             Hôtel Roho
# 53         2.01                     Hotel "Drei Kreuz"
# 54         2.57            Keleti International Resort
# 63         2.68                          #acnindiafy21
# 81         2.57  Embassy Suites by Hilton Oahu Kapolei
# 86         1.79                   Parra Hotel & Suites
# 124        0.69                         No hotel found
# 152        3.09                     Maui Seaside Hotel
# 157        1.53                         No hotel found
# 165        2.28                         Hôtel National
# 184        0.21                         No hotel found
# 189        0.89                 Hotel Lux- Grand Gaube
# 207        2.57            The Sanctuary Hotel and Spa
# 208        1.23                         Hotel Meuligou
# 211        2.06           Holiday Inn Express & Suites
# 220        1.37                      Bayan Yumbe Hotel
# 221        0.90                            Hotel Tiara
# 229        0.57                              Terra Sur
# 233        1.00                    Motel des voyageurs
# 240        0.35                         No hotel found
# 241        0.23                         No hotel found
# 265        1.37                         Jardines Hotel
# 298        2.71                              Esmeralda
# 334        1.18                         No hotel found
# 337        2.57                            Ibis Styles
# 338        1.03                            Motu Martin
# 340        0.74                              Sol y Mar
# 354        1.80                             Dena Hotel
# 355        2.39                     King Solomon Hotel
# 363        1.29                         No hotel found
# 375        3.09                    The Esplanade Hotel
# 381        2.95                         No hotel found
# 421        0.80                                Bregava
# 432        0.00           Bunk Bed Hotel Denpasar Bali
# 439        1.04                         No hotel found
# 450        2.31                     Almina Apart Hotel
# 473        0.84                         No hotel found
# 475        1.57                          Hotel Anggrek
# 501        0.53                                   Haip
# 509        1.95                      Hotel Royal Plaza
# 516        0.89                      Plaza sal paraiso
# 530        0.14                          Hôtel Magbetu
# 552        0.65                          Puri Ganjuran
# 563        2.32                            Vila Kebaya
# 567        2.28                            Joshi Hotel
# 569        1.44                      Rattana Sin Hotel

# %%
hotel_df.head()
# Out:
#             City Country      Lat       Lng  Humidity  Max Temp  Wind Speed  \
# 0           faya      SA  18.3851   42.4509        35     22.06        2.60
# 19  puerto ayora      EC  -0.7393  -90.3518        82     22.98        1.79
# 20        avarua      CK -21.2078 -159.7750        73     22.03        2.57
# 52       businga      CD   3.3333   20.8833        87     24.82        0.97
# 53          lasa      IT  46.6166   10.7002        68     23.49        2.01
#
#                               Hotel Name
# 0                         No hotel found
# 19  Hostal La Mirada De Solitario George
# 20                          Paradise Inn
# 52                            Hôtel Roho
# 53                    Hotel "Drei Kreuz"

# %%
# Step1 1 Configure the map plot
# Configure the map
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 2,
    color = "City",
    hover_cols = ["city","Humidity"])

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# Step1 1 Configure the map plot
# Configure the map
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "city",
    scale = 5,
    color = "City",
    hover_cols = ["Hotel Name", "Country"]
)


# Step 1 2 Display the map
hotel_map
# Out:
# WARNING:param.GeoPointPlot02078: Specified size dim transform (np.sqrt(dim('city'))*5) could not be applied, as not all dimensions could be resolved.
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Hotel Name,Country)
